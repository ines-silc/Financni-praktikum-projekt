# %%
#Definirajmo najprej grafe

#n = 4

#for G in graphs(n): # vsi možni grafi na n vozliščih
    #G.show()

# %%
# Za projekt rabimo grafe, ki so povezani z vsemi vozlišči

n = 9
gen = (G for G in graphs.nauty_geng('9 36:36')) #Grafi na n vozliščih, kjer je vsako vozlišče povezano z vsakim
x = next(gen)

print(x)

x
#Če je vsako vozlišče povezano z vsakim je minimalno število povezav n*(n-1)/2
# Out:
# Graph on 9 vertices
# Graph on 9 vertices

# %%
for i in x: #poglejmo če imajo vsi vse za sosede
    print i, x[i]
# Out:
# 0 [1, 2, 3, 4, 5, 6, 7, 8]
# 1 [0, 2, 3, 4, 5, 6, 7, 8]
# 2 [0, 1, 3, 4, 5, 6, 7, 8]
# 3 [0, 1, 2, 4, 5, 6, 7, 8]
# 4 [0, 1, 2, 3, 5, 6, 7, 8]
# 5 [0, 1, 2, 3, 4, 6, 7, 8]
# 6 [0, 1, 2, 3, 4, 5, 7, 8]
# 7 [0, 1, 2, 3, 4, 5, 6, 8]
# 8 [0, 1, 2, 3, 4, 5, 6, 7]

# %%
# Za problem trgovskega potnika potrebujemo utežen graf
