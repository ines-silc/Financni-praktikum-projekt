# %%
k = graphs.CompleteGraph(8)

i = 0
for u,v in k.edges(labels=0):
     k.set_edge_label(u, v, i)
     i += 1

# %%
k.weighted_adjacency_matrix()
# Out:
# [ 0  0  1  2  3  4  5  6]
# [ 0  0  7  8  9 10 11 12]
# [ 1  7  0 13 14 15 16 17]
# [ 2  8 13  0 18 19 20 21]
# [ 3  9 14 18  0 22 23 24]
# [ 4 10 15 19 22  0 25 26]
# [ 5 11 16 20 23 25  0 27]
# [ 6 12 17 21 24 26 27  0]

# %%
print k.edges()
# Out:
# [(0, 1, 0), (0, 2, 1), (0, 3, 2), (0, 4, 3), (0, 5, 4), (0, 6, 5), (0, 7, 6), (1, 2, 7), (1, 3, 8), (1, 4, 9), (1, 5, 10), (1, 6, 11), (1, 7, 12), (2, 3, 13), (2, 4, 14), (2, 5, 15), (2, 6, 16), (2, 7, 17), (3, 4, 18), (3, 5, 19), (3, 6, 20), (3, 7, 21), (4, 5, 22), (4, 6, 23), (4, 7, 24), (5, 6, 25), (5, 7, 26), (6, 7, 27)]

# %%
k
# Out:
# Complete graph: Graph on 8 vertices
